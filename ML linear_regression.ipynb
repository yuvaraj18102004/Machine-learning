# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Yuvaraj S\OneDrive\Desktop\16MLP\Cars.csv")
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
df.shape
# Out:
# (81, 5)

# %%
df.dtypes
# Out:
# HP       int64
# MPG    float64
# VOL      int64
# SP     float64
# WT     float64
# dtype: object

# %%
df.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df['HP'],df['MPG'])
plt.xlabel("HP")
plt.ylabel("MPG")
plt.show()

# %%
plt.scatter(df['VOL'],df['MPG'])
plt.xlabel("VOL")
plt.ylabel("MPG")
plt.show()

# %%
plt.scatter(df['SP'],df['MPG'])
plt.xlabel("SP")
plt.ylabel("MPG")
plt.show()

# %%
plt.scatter(df['WT'],df['MPG'])
plt.xlabel("WT")
plt.ylabel("MPG")
plt.show()

# %%
df.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
#Test of linearity is failed
#no multycollinearity is also failed
#no autoregression /autocorrelation is passed
x=df[['HP','VOL','SP','WT']]
x
# Out:
#      HP  VOL          SP         WT
# 0    49   89  104.185353  28.762059
# 1    55   92  105.461264  30.466833
# 2    55   92  105.461264  30.193597
# 3    70   92  113.461264  30.632114
# 4    53   92  104.461264  29.889149
# ..  ...  ...         ...        ...
# 76  322   50  169.598513  16.132947
# 77  238  115  150.576579  37.923113
# 78  263   50  151.598513  15.769625
# 79  295  119  167.944460  39.423099
# 80  236  107  139.840817  34.948615
#
# [81 rows x 4 columns]

# %%
y=df[['MPG']]
y
# Out:
#           MPG
# 0   53.700681
# 1   50.013401
# 2   50.013401
# 3   45.696322
# 4   50.504232
# ..        ...
# 76  36.900000
# 77  19.197888
# 78  34.000000
# 79  19.833733
# 80  12.101263
#
# [81 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr=LinearRegression()#modelbulding
mlr.fit(x,y)#model training
y_pred = mlr.predict(x)
y_pred
# Out:
# array([[43.44193477],
#        [42.38879289],
#        [42.27934147],
#        [42.53835981],
#        [42.17264802],
#        [43.02061916],
#        [42.32536062],
#        [48.07621852],
#        [48.28120247],
#        [40.79122814],
#        [41.52153227],
#        [47.80956747],
#        [39.95980269],
#        [41.52757889],
#        [41.76632332],
#        [41.6181448 ],
#        [41.15094046],
#        [47.98605515],
#        [41.30861046],
#        [37.87127922],
#        [38.57706414],
#        [37.35199705],
#        [37.89770285],
#        [39.5625144 ],
#        [39.93380662],
#        [46.73870908],
#        [35.48165898],
#        [38.78152504],
#        [38.24861192],
#        [36.00285298],
#        [34.84603989],
#        [37.21630246],
#        [37.13919796],
#        [34.82541399],
#        [37.22361389],
#        [37.53950097],
#        [39.27144845],
#        [38.24219888],
#        [38.54286458],
#        [35.9391722 ],
#        [34.2129755 ],
# ...

# %%
mlr.coef_
# Out:
# array([[-0.20544372, -0.33605084,  0.39562692,  0.40057409]])

# %%
mlr.intercept_
# Out:
# array([30.67733585])

# %%
((-0.20544372*49)+(-0.33605084*89)+(0.39562692*104.185353)+(0.40057409*28.762059)+30.67733585)
# Out:
# 43.44193473695407

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y,y_pred)
# Out:
# 0.7705372737359842

# %%
error= y-y_pred
error
# Out:
#           MPG
# 0   10.258747
# 1    7.624608
# 2    7.734060
# 3    3.157963
# 4    8.331584
# ..        ...
# 76  15.617904
# 77   1.298838
# 78   7.863547
# 79   7.517122
# 80  -3.458218
#
# [81 rows x 1 columns]

# %%
plt.scatter(x['HP'],error)
plt.show()

# %%
plt.scatter(x['VOL'],error)
plt.show()

# %%
plt.scatter(x['SP'],error)
plt.show()

# %%
plt.scatter(x['WT'],error)
plt.show()

# %%
homoscedasticity test is also failed

# %%
import seaborn as sns

# %%
sns.kdeplot(error)
plt.show()

# %%
normality test is also failed

# %%
x1=x[['HP','VOL','SP']]
mlr=LinearRegression()#modelbulding
mlr.fit(x1,y)#model training
y_pred1 = mlr.predict(x1)
y_pred1
# Out:
# array([[43.59076921],
#        [42.25679373],
#        [42.25679373],
#        [42.36149697],
#        [42.26954392],
#        [42.85590319],
#        [42.25679373],
#        [48.13220633],
#        [48.13220633],
#        [40.76616389],
#        [41.43447018],
#        [47.94095346],
#        [39.8656524 ],
#        [41.43447018],
#        [41.67942553],
#        [41.43447018],
#        [41.27332025],
#        [47.94095346],
#        [41.27332025],
#        [38.01721633],
#        [38.66367435],
#        [37.4600096 ],
#        [38.11461526],
#        [39.42853629],
#        [40.09224004],
#        [46.73897542],
#        [35.69723723],
#        [38.66367435],
#        [38.09466788],
#        [35.87282411],
#        [35.04066617],
#        [37.18309295],
#        [37.32689014],
#        [34.69005715],
#        [37.40254791],
#        [37.63924859],
#        [39.28726919],
#        [38.33839413],
#        [38.33839413],
#        [35.96910103],
#        [34.13369379],
# ...

# %%
r2_score(y,y_pred1)
# Out:
# 0.770368341321302
