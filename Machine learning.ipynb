# %%
import pandas as pd

# %%
d1 = pd.read_csv(r"C:\Users\Yuvaraj S\OneDrive\Desktop\16MLP\Salary_Data.csv")
d1
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
d1.shape
# Out:
# (30, 2)

# %%
d1.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
d1.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
d1.duplicated().sum()
# Out:
# np.int64(0)

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(d1['YearsExperience'],d1['Salary'])
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
x = d1[["YearsExperience"]]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y = d1["Salary"]
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
slr=LinearRegression() #model building

# %%
slr.fit(x,y)# model training
# Out:
# LinearRegression()

# %%
y_pred=slr.predict(x) #model prediction

# %%
y_pred.round(2)
# Out:
# array([ 36187.16,  38077.15,  39967.14,  44692.12,  46582.12,  53197.09,
#         54142.09,  56032.08,  56032.08,  60757.06,  62647.05,  63592.05,
#         63592.05,  64537.05,  68317.03,  72097.02,  73987.01,  75877.  ,
#         81546.98,  82491.97,  90051.94,  92886.93, 100446.9 , 103281.89,
#        108006.87, 110841.86, 115566.84, 116511.84, 123126.81, 125016.8 ])

# %%
slr.coef_
# Out:
# array([9449.96232146])

# %%
slr.intercept_
# Out:
# np.float64(25792.200198668717)

# %%
#alpla 9449.96232146
#beta 25792.200198668717
#alpha x+beta
( 9449.96232146*10.5)+ 25792.200198668717
# Out:
# 125016.80457399873

# %%
error=y-y_pred
error
# Out:
# 0      3155.841248
# 1      8127.848783
# 2     -2236.143681
# 3     -1167.124842
# 4     -6691.117306
# 5      3444.909069
# 6      6007.912837
# 7     -1587.079627
# 8      8412.920373
# 9     -3568.060788
# 10      570.946748
# 11    -7798.049484
# 12    -6635.049484
# 13    -7456.045717
# 14    -7206.030645
# 15    -4159.015574
# 16    -7958.008038
# 17     7210.999498
# 18     -183.977895
# 19    11448.025873
# 20     1686.056015
# 21     5386.067319
# 22      855.097462
# 23    10530.108765
# 24     1424.127605
# 25    -5259.861092
# 26     1402.157748
# 27    -3876.838485
# 28     -735.812110
# 29    -3144.804574
# Name: Salary, dtype: float64

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y,y_pred)
# Out:
# 0.9569566641435086

# %%
mean_squared_error(y,y_pred)
# Out:
# 31270951.722280957

# %%
plt.scatter(x, y, label='Actual value')
plt.plot(x,y_pred, label='Predicted value', color="black")
plt.scatter(x,y_pred, label='Predicted value')
plt.legend()
plt.show()
